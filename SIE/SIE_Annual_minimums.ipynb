# %%
### Import modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import datetime
import pandas as pd

# %%
### Directory and time
directoryfigure = '/Users/fridaperez/Developer/repos/phase_project/SIE/'

# %%
# Load url
data = '/Users/fridaperez/Developer/repos/phase_project/SIE/Decade_Means.csv'
df = pd.read_csv(data)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming your dataframe is named 'df'

# Create a day of year (doy) column
df['DOY'] = np.arange(1, len(df) + 1)

# Extract relevant data
doy = df['DOY']
mean_1990s = df['Mean1990s']
mean_2000s = df['Mean2000s']
mean_2010s = df['Mean2010s']
values_2023 = df['2023']

# Find lowest values for each year
lowest_values = df.iloc[:, 5:].idxmin(axis=1)
lowest_values_values = df.min(axis=1)

# Plotting
plt.figure(figsize=(10, 6))

# Plot mean values for each decade
plt.plot(doy, mean_1990s, label='Mean 1990s', linestyle='--', marker='o')
plt.plot(doy, mean_2000s, label='Mean 2000s', linestyle='--', marker='o')
plt.plot(doy, mean_2010s, label='Mean 2010s', linestyle='--', marker='o')

# Plot values for 2023
plt.plot(doy, values_2023, label='2023', linestyle='-', marker='o')

# Scatter plot for lowest values
plt.scatter(doy, lowest_values_values, color='red', label='Lowest Values', marker='x')

# Add labels and title
plt.xlabel('Day of Year')
plt.ylabel('Sea Ice Extent')
plt.title('Arctic Sea Ice Extent (1990s, 2000s, 2010s, 2023)')

# Define x labels explicitly
xlabels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(doy, xlabels)

# Show plot
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming your dataframe is named 'df'

# Create a day of year (doy) column
df['DOY'] = np.arange(1, len(df) + 1)

# Extract relevant data for January to April (1-120)
df_jan_apr = df[df['DOY'] <= 120]

# Extract relevant data
doy = df_jan_apr['DOY']
mean_1990s = df_jan_apr['Mean1990s']
mean_2000s = df_jan_apr['Mean2000s']
mean_2010s = df_jan_apr['Mean2010s']
values_2023 = df_jan_apr['2023']

# Find lowest values for each year
lowest_values = df_jan_apr.iloc[:, 5:].idxmin(axis=1)
lowest_values_values = df_jan_apr.min(axis=1)

# Plotting
plt.figure(figsize=(10, 6))

# Plot mean values for each decade
plt.plot(doy, mean_1990s, label='Mean 1990s', linestyle='--', marker='o')
plt.plot(doy, mean_2000s, label='Mean 2000s', linestyle='--', marker='o')
plt.plot(doy, mean_2010s, label='Mean 2010s', linestyle='--', marker='o')

# Plot values for 2023
plt.plot(doy, values_2023, label='2023', linestyle='-', marker='o')

# Scatter plot for lowest values
plt.scatter(doy, lowest_values_values, color='red', label='Lowest Values', marker='x')

# Add labels and title
plt.xlabel('Day of Year')
plt.ylabel('Sea Ice Extent')
plt.title('Arctic Sea Ice Extent (1990s, 2000s, 2010s, 2023) - January to April')

# Define x labels explicitly
xlabels = ['Jan', 'Feb', 'Mar', 'Apr']
plt.xticks(doy, xlabels)

# Set x-axis limits
plt.xlim(1, 120)

# Show plot
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming your dataframe is named 'df'

# Create a day of year (doy) column
df['DOY'] = np.arange(1, len(df) + 1)

# Extract relevant data for January to April (1-120)
df_jan_apr = df[df['DOY'] <= 120]

# Extract relevant data
doy = df_jan_apr['DOY']
mean_1990s = df_jan_apr['Mean1990s']
mean_2000s = df_jan_apr['Mean2000s']
mean_2010s = df_jan_apr['Mean2010s']
values_2023 = df_jan_apr['2023']

# Find lowest values for each year
lowest_values = df_jan_apr.iloc[:, 5:].idxmin(axis=1)
lowest_values_values = df_jan_apr.min(axis=1)

# Plotting
plt.figure(figsize=(10, 6))

# Plot mean values for each decade
plt.plot(doy, mean_1990s, label='Mean 1990s', linestyle='--', marker='o')
plt.plot(doy, mean_2000s, label='Mean 2000s', linestyle='--', marker='o')
plt.plot(doy, mean_2010s, label='Mean 2010s', linestyle='--', marker='o')

# Plot values for 2023
plt.plot(doy, values_2023, label='2023', linestyle='-', marker='o')

# Scatter plot for lowest values
plt.scatter(lowest_values.index, lowest_values_values, color='red', label='Lowest Values', marker='x')

# Add labels for lowest values
for index, value in zip(lowest_values.index, lowest_values_values):
    plt.text(index, value, f'{value:.2f}', color='w', fontsize=7)

# Add labels and title
plt.xlabel('Day of Year')
plt.ylabel('Sea Ice Extent')

# Define x labels explicitly
xlabels = ['Jan', 'Feb', 'Mar', 'Apr']
plt.xticks(doy, xlabels)

# Set x-axis limits
plt.xlim(1, 120)

# Show plot
plt.legend()
plt.show()

# %%
df
# Out:
#       Date  Mean1990s  Mean2000s  Mean2010s   1990   1991   1992   1993  \
# 0      1/1     6.7522     7.2346     7.1056  6.771  7.095  6.656  6.284
# 1      1/2     6.5844     7.0431     6.9426  6.621  6.928  6.458  6.079
# 2      1/3     6.4251     6.8280     6.7818  6.449  6.795  6.278  5.884
# 3      1/4     6.2741     6.6641     6.6379  6.316  6.684  6.053  5.721
# 4      1/5     6.1419     6.5074     6.4803  6.198  6.519  5.963  5.555
# ..     ...        ...        ...        ...    ...    ...    ...    ...
# 361  12/27     7.7054     8.2021     7.8920  7.916  7.716  7.345  7.225
# 362  12/28     7.5201     7.9992     7.7120  7.815  7.611  7.062  7.132
# 363  12/29     7.3133     7.8170     7.5169  7.592  7.372  6.772  7.008
# 364  12/30     7.1028     7.6174     7.3279  7.350  7.111  6.573  6.907
# 365  12/31     6.9327     7.4388     7.1735  7.203  6.829  6.403  6.893
#
#       1994   1995  ...   2015   2016   2017   2018   2019   2020   2021  \
# ...
